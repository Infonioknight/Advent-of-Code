# %%
# # data = open("Day21test.txt", 'r').read().split('\n')
# data = open("Garden.txt", 'r').read().split('\n')

# %%
# from copy import deepcopy
# from collections import deque

# for line in data:
#     if 'S' in line:
#          row, col = data.index(line), line.index('S')

# prev = deque()
# cur_new = set()
# counter = 0
# prev.append((row, col))

# while counter < 1000:
#     cur_new = set()
#     # print(prev)
#     while len(prev) > 0:
#         r, c = prev.popleft()
#         # print(r, c)
#         for dr, dc in [[0, 1], [1, 0], [0, -1], [-1, 0]]: 
#             if data[(r + dr) % len(data)][(c + dc) % len(data)] != '#':
#                 cur_new.add((r+dr, c+dc))
#     counter += 1
#     for item in cur_new:
#         prev.append(item)
#     print(len(cur_new))
# Out:
# 4
# 8
# 13
# 22
# 29
# 42
# 54
# 68
# 85
# 103
# 125
# 143
# 167
# 193
# 222
# 248
# 281
# 310
# 349
# 381
# 420
# 461
# 499
# 543
# 580
# 628
# 672
# 728
# 772
# 836
# 881
# 942
# 986
# 1056
# 1102
# 1190
# 1226
# 1314
# 1351
# 1463
# 1500
# 1613
# 1650
# 1764
# 1796
# 1924
# 1960
# 2088
# 2124
# 2264
# 2302
# 2443
# 2482
# 2632
# 2669
# 2826
# 2857
# 3023
# 3057
# 3237
# 3267
# 3482
# 3525
# 3748
# 3787
# 4012
# 4055
# 4284
# 4296
# 4529
# 4549
# 4771
# 4803
# 5023
# 5064
# 5288
# 5337
# 5552
# 5614
# 5841
# 5909
# 6125
# 6191
# 6417
# 6496
# 6713
# 6795
# 7023
# 7120
# 7337
# 7444
# 7662
# 7758
# 7986
# 8095
# 8318
# 8434
# 8660
# 8780
# 9015
# 9150
# 9380
# 9514
# 9734
# 9874
# 10105
# 10261
# 10488
# 10628
# 10865
# 11024
# 11265
# 11426
# 11659
# 11834
# 12066
# 12241
# 12474
# 12662
# 12879
# 13074
# 13311
# 13518
# 13751
# 13942
# 14174
# 14387
# 14611
# 14839
# 15066
# 15291
# 15522
# 15758
# 15980
# 16228
# 16441
# 16700
# 16921
# 17183
# 17421
# 17677
# 17907
# 18172
# ...
